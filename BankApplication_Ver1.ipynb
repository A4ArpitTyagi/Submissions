# %%
#Importing random for random numbers and sys for system exit when user wants it
import random
import sys

# This method is to print the welcome message when somebody uses the programme.
def welcome():
    welcome = "WELCOME"
    z=0            # 'z' is nothing but the number of lines in which welcome will be printed.
    while z<5:
        for i in welcome:
            if i == 'W':
                if z ==0:
                    print("*           *",end='   ')
                elif z==1:
                    print(" *         * ",end='   ')
                elif z==2:
                    print("  *   *   *  ",end='   ')
                elif z==3:
                    print("   *     *   ",end='   ')
                elif z==4:
                    print("    *   *    ", end='   ')
            if i == 'E':
                if z ==0:
                    print("*************",end='   ')
                elif z==1:
                    print("*            ",end='   ')
                elif z==2:
                    print("*************",end='   ')
                elif z==3:
                    print("*            ",end='   ')
                elif z==4:
                    print("*************", end='   ')
            if i == 'L':
                if z ==0:
                    print("*            ",end='   ')
                elif z==1:
                    print("*            ",end='   ')
                elif z==2:
                    print("*            ",end='   ')
                elif z==3:
                    print("*            ",end='   ')
                elif z==4:
                    print("*************", end='   ')
            if i == 'C':
                if z ==0:
                    print("*************",end='   ')
                elif z==1:
                    print("*            ",end='   ')
                elif z==2:
                    print("*            ",end='   ')
                elif z==3:
                    print("*            ",end='   ')
                elif z==4:
                    print("*************",end='   ')
            if i == 'O':
                if z ==0:
                    print(" *********** ",end='   ')
                elif z==1:
                    print("*           *",end='   ')
                elif z==2:
                    print("*           *",end='   ')
                elif z==3:
                    print("*           *",end='   ')
                elif z==4:
                    print(" *********** ",end='   ')
            if i == 'M':
                if z ==0:
                    print("    *   *    ", end='   ')
                elif z==1:
                    print("   *     *   ",end='   ')
                elif z==2:
                    print("  *   *   *  ",end='   ')
                elif z==3:
                    print(" *         * ",end='   ')
                elif z==4:
                     print("*           *",end='   ')

        z+=1
        print()


# class BANK will contain all the possible actions whici user can do in the ATM.
class BANK():
 
    
# Initialized the account with the user inputted name and account number and initial balance 0    
    def __init__(self, name, account_number, account_balance = 0):
        self.name = name
        self.account_number = account_number
        self.account_balance = account_balance

# This will print the current balance of the user who wants to check the balance. 
    def check_balance(self):
        print("CURRENT BALANCE IS: $ ", self.account_balance)
        print()
        
# This method will print the account detail if user wants to know: Name, Account number and Balance.        
    def account_detail(self):
        print(f"HI {self.name.upper()}. YOUR ACCOUNT DETAILS ARE: \n")
        #print("\n----------ACCOUNT DETAILS----------")
        print(f"ACCOUNT HOLDER NAME: {self.name.upper()}")
        print(f"ACCOUNT NUMBER: {self.account_number}")
        print(f"CURRENT ACCOUNT BALANCE: $ {self.account_balance}\n")

# This method will help user depositing money into his account.         
    def deposit(self, deposit_amount):
        self.deposit_amount = deposit_amount
        self.account_balance += self.deposit_amount
        print("CURRENT ACCOUNT BALANCE IS: $", self.account_balance)
        print()
# This method will help user in withdrewing money from his account.
    def withdraw(self, withdraw_amount):
        self.withdraw_amount = withdraw_amount
        if self.withdraw_amount > self.account_balance:
            print(f"INSUFFICIENT FUND! || CURRENT BALANCE IS $ {self.account_balance} only")
            print("TRY AGAIN !!")
            print()
        else:
            self.account_balance -= self.withdraw_amount
            print(f"$ {self.withdraw_amount} HAS BEEN WITHDRAWN")
            print("BALANCE AFTER WITHDRAWL IS $ ", self.account_balance)
            print()

# This is the method which will call all aboce methods as a whole in a loop. 
# That loop will be terminated only when user will input 5 as the option.

    def processing(self):
        
        # safety_counter is the three time limit for atm pin code. It works with loop to assure the safety of ATM.
        safety_counter = 0
        for counter in range(0,3):
            pin = int(input("ENTER THE 4 DIGIT PINCODE: "))
            if pin != 1111:
                safety_counter +=1
                if safety_counter == 1:
                    print("THIS IS NOT THE CORRECT PIN. TRY AGAIN!!")
                elif safety_counter==2:
                    print("INCORRECT PIN - TWICE IN A ROW. YOU HAVE ONE CHANCE LEFT!!")
                elif safety_counter ==3:
                    print("YOUR CARD IS BLOCKED. PLEASE CONTACT CUSTOMER SERVICES ASAP! ")
                    sys.exit()
                continue
            else:
                print()
                
                # This is an infinity loop will terminate only when user will enter 5.
                while True:
                    # try block will give user some options and will allow user to enter the input.
                    try:
                        print("""
                ####################
                    Options:
                    1. ACCOUNT DETAIL
                    2. CHECEK CURRENT BALANCE
                    3. DEPOSIT
                    4. WITHDRAWL
                    5. EXIT
                #####################
                """)
                        user_input = int(input("PLEASE ENTER 1, 2, 3, 4 OR 5: "))
                        print()
                        
                    # If user enters any other number than thr given options, it will be caught in except block.
                    except:
                        print("WRONG NUMBER: PLEASE ENTER 1, 2, 3, 4, or 5 ONLY!!\n")
                        print()
                        continue
                        
                    # if there is no exception then else block will run below.
                    else:
                        if user_input== 1:
                            arpit.account_detail()                                # 1 for account detail
                        elif user_input == 2:
                            arpit.check_balance()                                 # 2 for balance checking
                        elif user_input == 3:
                            amount = int(input("ENTER AMOUNT TO BE DEPOSITED $: "))
                            arpit.deposit(amount)                                 # 3 for depositing amount
                        elif user_input == 4:
                            amount = int(input("ENTER AMOUNT TO BE WITHDRAWN $: "))
                            arpit.withdraw(amount)                                # 4 for withdrawl
                        elif user_input == 5:                                     # 5 for system exit
                            print(f"""
                        Transanction Slip..............
                  #########################################
                      TRANSANCTION IS COMPLETED.                         
                      TRANSANCTION NUMBER: {random.randint(100, 1000000)} 
                      USER NAME: {self.name.upper()}                  
                      USER ACCOUNT NUMBER: {self.account_number}                
                      CURRENT BALANCE: $ {self.account_balance}                    

                      THANKS. VISIT AGAIN.                  
                  #########################################
                  """)                                                           # This will generate a exit slip
                            sys.exit()                                           # for the user
                            #break
                            
                            

# It will print the big 'welcome' on the screen before starting anything.                            
welcome()
print()
print("**************************************BANK OF INDIA IS AT YOUR SERVICE***************************************")
print()
print("----------ACCOUNT CREATION IN PROCESS--------------")
customer_name = input("ENTER YOUR NAME: ")
account_number = input("ENTER YOUR ACCOUNT NUMBER: ")
print("ACCOUNT CREATED SUCCESSFULLY!! CONGRATS.....\n")
 
# arpit is the object of class BANK and we need to provide two arguments for the call : Name and Account number.
arpit = BANK(customer_name,account_number)
 
# it is an infinity loop which will terminate only when user will enter 'n' or 'N'.
while True:
    options = input("DO YOU WANT TO USE BANK FACILITIES: Y FOR 'YES' || N FOR 'NO' ")
    print()
    if options == "y" or options == 'Y':
        arpit.processing()
    elif options == "n" or options == "N":
        print(f"THANK YOU FOR CHOOSING US {customer_name.upper()}. VISIT AGAIN!!")
        break
    else:
        print("INCORRECT INPUT. PLEASE ENTER 'y'/'Y' FOR 'YES' AND 'n'/'N' FOR NO.\n")
# Out:
# *           *   *************   *               *************    ***********        *   *       *************
#  *         *    *               *               *               *           *      *     *      *
#   *   *   *     *************   *               *               *           *     *   *   *     *************
#    *     *      *               *               *               *           *    *         *    *
#     *   *       *************   *************   *************    ***********    *           *   *************
#
# **************************************BANK OF INDIA IS AT YOUR SERVICE***************************************
#
# ----------ACCOUNT CREATION IN PROCESS--------------
# ENTER YOUR NAME: john cena
# ENTER YOUR ACCOUNT NUMBER: 1234
# ACCOUNT CREATED SUCCESSFULLY!! CONGRATS.....
#
# DO YOU WANT TO USE BANK FACILITIES: Y FOR 'YES' || N FOR 'NO' y
#
# ENTER THE 4 DIGIT PINCODE: 1111
#
#
#                 ####################
#                     Options:
# ...
